# %%
import pandas as pd
from autocleanml import AutoCleanML

# %%
from sklearn.datasets import load_iris
import pandas as pd


iris = load_iris()


X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.Series(iris.target, name="target")


df = pd.concat([X, y], axis=1)

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
clean = AutoCleanML(target='target',model_type='linear')

# %%
X_train,X_test,y_train,y_test,report = clean.fit_transform(df)
print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# ================================================================================
#                     🚀 AutoCleanML - Smart Data Cleaning Pipeline
# ================================================================================
#
# 📊 Original dataset: 150 rows × 5 columns
# 🎯 Target column: 'target'
# 📋 Task type: classification
#
# ✂️  Splitting data: 80% train, 20% test
#    Using stratified split (classification)
#    Train: 120 rows
#    Test:  30 rows
#
# ================================================================================
#                          CLEANING TRAINING DATA
# ================================================================================
#
# 🧹 Step 1/11: Removing duplicate rows...
#    ✓ Removed 1 duplicate rows
#
# 🔧 Step 2/11: Correcting data types...
#    ✓ All data types correct
#
# 💉 Step 3/11: Smart missing value imputation...
#
# ======================================================================
#                     MISSING VALUE IMPUTATION REPORT
# ======================================================================
#
# ✓ No missing values detected!
#
# 🎯 Step 4/11: Advanced outlier detection...
#
# ======================================================================
#                     OUTLIER DETECTION & HANDLING REPORT
# ======================================================================
#
# 📊 Method: AUTO
# 📊 Action: CAP
#
# 📊 Columns processed: 1
# 📊 Total outliers: 1
#
# ----------------------------------------------------------------------
# Column               Outliers        Method       Reason
# ----------------------------------------------------------------------
# sepal width (cm)     1 (0.84%)       zscore       data appears normally distribu
# ======================================================================
#
# ✨ Step 5/11: Feature extraction (creating new features)...
#    ✓ Numeric: Created 15 features
#
# 🏷️  Step 6/11: Smart categorical encoding...
#    ✓ Encoded categorical features
#
# 🔍 Step 7/11: Removing zero-variance features...
#
# ⚡ Step 8/11: Selecting important features (max 100)...
#    Detected task: classification
#    Removed 13 multicollinear features
#    Feature selection: 19 → 6 features
#    Removed 13 low-importance features
#    ✓ Selected 6 most important features (from 19)
#
# 📏 Step 9/11: Intelligent transformation & scaling (model_type='linear')...
#    ✓ Transformed 1 skewed features
#       - sepal length (cm)_div_petal width (cm): log (skewness was 1.86)
#    ✓ Scaling: standard
#       sepal length (cm)_div_petal width (cm): Applied log transform (original skewness=1.86)
#       Linear/distance-based model with clean data → StandardScaler (assumes normal distribution, zero mean, unit variance)
#
# ⚖️  Step 10/11: Checking for class imbalance...
#    ✓ Dataset is balanced (ratio: 0.975)
#
# ================================================================================
#                          CLEANING TEST DATA (Step 11/11)
# ================================================================================
#
# ✓ Test data cleaned using training parameters (no data leakage)
#
# ================================================================================
#                               ✅ CLEANING COMPLETE!
# ================================================================================
#
# 📊 Original data: 150 rows × 5 columns
# 📊 Training set: 119 rows × 6 features
# 📊 Test set:     30 rows × 6 features
#
# ✅ VERIFIED: Training set has 0 NaN values
#
# ✅ VERIFIED: Test set has 0 NaN values
#
# ✨ Added 2 engineered features
#
# 🎯 Ready for model training!
# 🎯 No data leakage - test data never seen during training
#
# ================================================================================
# (119, 6) (30, 6)
# (119,) (30,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
print("LogisticRegression")
model1 = LogisticRegression()
model1.fit(X_train,y_train)
y_pred1 = model1.predict(X_test)
print("Accuracy = ",accuracy_score(y_test,y_pred1)*100)
# Out:
# LogisticRegression
# Accuracy =  96.66666666666667

# %%
print("DecisionTreeClassifier")
model2 = DecisionTreeClassifier(max_depth=10,random_state=42)
model2.fit(X_train,y_train)
y_pred2 = model2.predict(X_test)
print("Accuracy = ",accuracy_score(y_test,y_pred2)*100)
# Out:
# DecisionTreeClassifier
# Accuracy =  96.66666666666667

# %%
from sklearn.ensemble import VotingClassifier
estimators = [('lr',model1),('dt',model2)]
model3 = VotingClassifier(estimators=estimators,voting='soft')
model3.fit(X_train,y_train)
y_pred3 = model3.predict(X_test)
print("Voting Classifier")

print("Accuracy=",accuracy_score(y_test,y_pred3)*100)
# Out:
# Voting Classifier
# Accuracy= 96.66666666666667
