# %%
import pandas as pd 
import numpy as np
from autocleanml import AutoCleanML

# %%
df = pd.read_csv('../data/laptop_data.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
clean = AutoCleanML(target='Price',model_type='linear')

# %%
X_train,X_test,y_train,y_test,report = clean.fit_transform(df)
# Out:
# 🗑️  Removed 1 index column(s): ['Unnamed: 0']
#
# ...
#                     🚀 AutoCleanML - Smart Data Cleaning Pipeline
# ...
#
# 📊 Original dataset: 1303 rows × 11 columns
# 🎯 Target column: 'Price'
# 📋 Task type: regression
#
# ✂️  Splitting data: 80% train, 20% test
#    Using random split (regression)
#    Train: 1042 rows
#    Test:  261 rows
#
# ...
#                          CLEANING TRAINING DATA
# ...
#
# 🧹 Step 1/11: Removing duplicate rows...
#    ✓ Removed 19 duplicate rows
#
# 🔧 Step 2/11: Correcting data types...
#    ✓ All data types correct
#
# 💉 Step 3/11: Smart missing value imputation...
#
# ...
#                     MISSING VALUE IMPUTATION REPORT
# ...
#
# ✓ No missing values detected!
#
# 🎯 Step 4/11: Advanced outlier detection...
#
# ...
#                     OUTLIER DETECTION & HANDLING REPORT
# ...
#
# 📊 Method: AUTO
# 📊 Action: CAP
#
# 📊 Columns processed: 1
# 📊 Total outliers: 31
#
# ----------------------------------------------------------------------
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score

# %%
model1 = LinearRegression()
model1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred1 = model1.predict(X_test)
print("r2_score = ",r2_score(y_test,y_pred1))
# Out:
# r2_score =  0.7855724094317784

# %%
model2 = DecisionTreeRegressor(max_depth=9,random_state=42)
model2.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=9, random_state=42)

# %%
y_pred2 = model2.predict(X_test)
print("R2_score = ",r2_score(y_test,y_pred2))
# Out:
# R2_score =  0.710978889392024

# %%
model3 = RandomForestRegressor(
    n_estimators=500,
    max_depth=10,
    n_jobs=-1,
    random_state=42
    )

# %%
model3.fit(X_train,y_train)
y_pred3 = model3.predict(X_test)
print("R2_Score = ",r2_score(y_test,y_pred3))
# Out:
# R2_Score =  0.8088342119257661

# %%
model4 = GradientBoostingRegressor(
        n_estimators=700,
        learning_rate=0.05,
        max_depth=3,
        random_state=42
    )

model4.fit(X_train,y_train)
y_pred4 = model4.predict(X_test)
print("R2 Score = ",r2_score(y_test,y_pred4))
# Out:
# R2 Score =  0.8986969513034873
